# %%
import pandas as pd
import matplotlib.pyplot as plt
from config import DATA_DIR, CHARTS_DIR

# %%
print("Loading data to RAM...")
csv_file_path = DATA_DIR / 'processed_data.csv'

df = pd.read_csv(csv_file_path)
print("Data loaded successfully!")
# Out:
# Loading data to RAM...
# Data loaded successfully!

# %%
TARGET_CAN_ID = 'all'
STEP = 10

start_time = df['Timestamp'].min()

byte_cols = [f'Byte{i}' for i in range(1, 9)]
colors = ['red', 'blue', 'green', 'darkorange', 'purple', 'saddlebrown', 'deeppink', 'teal']

if str(TARGET_CAN_ID).lower() == 'all':
    target_ids = sorted(df['CAN_ID'].unique())
else:
    target_ids = [TARGET_CAN_ID]

for can_id in target_ids:
    df_mod = df[df['CAN_ID'] == can_id].sort_values(by='Timestamp')

    if STEP > 1:
        df_mod = df_mod.iloc[::STEP, :]

    if len(df_mod) < 10:
        continue

    time_elapsed = df_mod['Timestamp'] - start_time

    plt.figure(figsize=(30, 10), dpi=200)

    for byte_name, color in zip(byte_cols, colors):
        plt.plot(time_elapsed, df_mod[byte_name], label=byte_name, color=color, linewidth=0.8, alpha=0.85)

    plt.title(f'Byte values over time for CAN ID: {can_id} (Sampled every {STEP} frames)', fontsize=18)

    plt.xlabel('Time elapsed from start [s]', fontsize=16)

    plt.ylabel('Byte decimal (0 - 255)', fontsize=16)
    plt.ylim(-10, 265)
    plt.grid(True, linestyle='--', alpha=0.6)

    leg = plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), title="Bytes")
    for line in leg.get_lines():
        line.set_linewidth(3.0)

    plt.tight_layout()
    #plt.savefig(f'{CHARTS_DIR}/step/step_{can_id}.png')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 44
#      40         line.set_linewidth(3.0)
#      41
#      42     plt.tight_layout()
#      43     # plt.savefig(f'{CHARTS_DIR}/step/step_{can_id}.png')
# ---> 44     plt.show()
#
# File F:\PycharmProjects\CAN\.venv\Lib\site-packages\matplotlib\pyplot.py:614, in show(*args, **kwargs)
#     570 """
#     571 Display all open figures.
#     572
#    (...)    611 explicitly there.
#     612 """
#     613 _warn_if_gui_out_of_main_thread()
# --> 614 return _get_backend_mod().show(*args, **kwargs)
#
# File F:\PycharmProjects\CAN\.venv\Lib\site-packages\matplotlib_inline\backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
# ...
